# %%
import pandas
import seaborn

# %%
data: pandas.DataFrame = pandas.concat(
    [
        pandas.read_parquet("../02--naive-personas/reports/cross_evaluation.parquet"),
        pandas.read_parquet("../03--value-driven-personas/reports/cross_evaluation.parquet"),
    ],
    keys=["naive", "value-driven"],
    names=["method"],
)
data
# Out:
# sample                                anonymous                         \
# group                                   liberal  moderate conservative
# method       model       persona
# naive        llama3.1:8b liberal       0.389333  0.622000     0.946000
#                          moderate      0.475333  0.244000     0.444000
#                          conservative  1.008000  0.758000     0.754000
#              llama2:70b  liberal       0.507333  0.557333     0.590667
#                          moderate      0.754000  0.280000     0.232000
# ...                                         ...       ...          ...
# value-driven qwen:72b    moderate      1.018667  0.768667     0.764667
#                          conservative  1.538667  1.288667     1.284667
#              qwen2:72b   liberal       0.248667  0.685333     1.009333
#                          moderate      0.616667  0.426667     0.424000
#                          conservative  0.996000  0.530000     0.344667
#
# ...

# %%
(
    pandas.read_parquet("../02--naive-personas/reports/cross_evaluation.parquet")
    .melt(ignore_index=False)
    .reset_index()
    .pipe(lambda _df: _df[_df["persona"] == _df["group"]])
    .groupby("sample")
    ["value"]
    .agg(["mean", "std"])
)
# Out:
#                mean       std
# sample
# anonymous  0.579454  0.329169
# korean     0.859633  0.394934
# us         0.808999  0.330365

# %%
subset: pandas.DataFrame = (
    data.melt(ignore_index=False)
    .reset_index()
    .pipe(lambda _df: _df[_df["persona"] == _df["group"]])
    .rename(columns={"value": "distance", "method": "prompting"})
)
subset
# Out:
#         prompting         model       persona     sample         group  \
# 0           naive   llama3.1:8b       liberal  anonymous       liberal
# 3           naive    llama2:70b       liberal  anonymous       liberal
# 6           naive    llama3:70b       liberal  anonymous       liberal
# 9           naive  llama3.1:70b       liberal  anonymous       liberal
# 12          naive    mistral:7b       liberal  anonymous       liberal
# ..            ...           ...           ...        ...           ...
# 635  value-driven      phi3:14b  conservative     korean  conservative
# 638  value-driven      gemma:7b  conservative     korean  conservative
# 641  value-driven    gemma2:27b  conservative     korean  conservative
# 644  value-driven      qwen:72b  conservative     korean  conservative
# 647  value-driven     qwen2:72b  conservative     korean  conservative
#
#      distance
# 0    0.389333
# 3    0.507333
# 6    0.488000
# 9    0.610667
# 12   0.813521
# ..        ...
# ...

# %%
ax = seaborn.barplot(data=subset, x="distance", y="persona", hue="prompting")

for container in ax.containers:
    ax.bar_label(container, label_type="center")

ax.figure.suptitle("Comparison of naïve and data-driven prompted personas on MFQ.")
ax.figure.text(
    0.5,
    -0.075,
    "The reported distance describes the mean absolute error between a human survey population and the corresponding LLMs persona-prompted results. Lower is better.",
    wrap=True,
    horizontalalignment="center",
    fontsize=10,
)
ax.figure.text(
    0.5,
    0.915,
    "Münker, Simon. Towards in-context Value-driven Statement Alignment with Moral Foundations Theory.",
    wrap=True,
    horizontalalignment="center",
    fontsize=8,
)
ax.get_figure().savefig("reports/bar.naive_vs_value_driven.pdf", bbox_inches="tight")
